# %% [markdown]
# # KFold-VGG16-PetsHI(BreasKHist weights)
#
# ---

# %% [markdown]
# Instituto Federal de Educação, Ciência e Tecnologia do Maranhão.
#
# Aluno: Vinícius Barbosa Da Silva
#
# Matrícula: 20181SI0007
#
# Orientador: Omar Andres Carmona Cortes
#
# Projeto: Uma Base de Dados para Identificação de Câncer em PETs Usando Aprendizagem Profunda
#
# ---

# %% [markdown]
# O conjunto de dados possui 592 imagens totais divididas em benign(mama normal) = 220 e malignant(neoplasia) = 372. o conjunto foi aumentado em 10x as imagens de benign e 5x as imagens de malignant com as transformações: flip vertical, flip horizontal e random crop(0, 100).
#
# Neste Notebook foi feito o 2 Kfold no modelo VGG16, um sem pesos pré-treinados BreakHis, outro com pesos pré-treinados do BreasKHis. Na utilização do modelo pré treinado BreakHis há um double transfer learning no qual a VGG16 usa pesos do imagenet e depois do BreasKHis com ajuste fino para congelar camadas. Com K = 5.

# %% [markdown]
# ---

# %% [markdown]
# ## Import das Bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout,Flatten,Dense,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from keras.backend import clear_session

import sklearn
from sklearn.model_selection import KFold, train_test_split


import pathlib
import os

# %% [markdown]
# ## Extraindo PATH e LABELS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

path = '/content/drive/MyDrive/Base de dados de HI Pets.zip'
zip_object = zipfile.ZipFile(file = path, mode = 'r')
zip_object.extractall('./')
zip_object.close()

# %%
data_path = pathlib.Path(r'/content/Base de dados de HI Pets')

# glob all 'jpg' image files
img_path = list(data_path.glob('**/*.jpg'))

# split label names do diretório
img_labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], img_path))

# %%
# Criar um DataFrame
pd_img_path = pd.Series(img_path, name='PATH').astype(str)
pd_img_labels = pd.Series(img_labels, name='LABELS').astype(str)
img_df = pd.merge(pd_img_path, pd_img_labels, right_index=True, left_index=True)

# Amostras aleatórias
img_df = img_df.sample(frac=1).reset_index(drop=True)

# Mostrar as primeiras linhas do DataFrame após a transformação
img_df.head()

# %%
img_df['LABELS'].value_counts(ascending=True)
# Out:
# benign       220
# malignant    372
# Name: LABELS, dtype: int64

# %%
plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i+1)
  plt.imshow(plt.imread(img_df.PATH[i]))
  plt.title(img_df.LABELS[i])
  plt.axis("off")

# %% [markdown]
# ## Dividindo em Teste e Treino

# %%
train_dataset, test_dataset = train_test_split(img_df, train_size=0.8, shuffle=True, stratify=img_df['LABELS'])
print("Number of train data:", train_dataset.shape[0])
print("Number of test data:", test_dataset.shape[0])
# Out:
# Number of train data: 473
# Number of test data: 119

# %%
train_dataset
# Out:
#                                                   PATH     LABELS
# 107  /content/Base de dados de HI Pets/benign/class...     benign
# 106  /content/Base de dados de HI Pets/malignant/cl...  malignant
# 318  /content/Base de dados de HI Pets/benign/class...     benign
# 190  /content/Base de dados de HI Pets/malignant/cl...  malignant
# 290  /content/Base de dados de HI Pets/malignant/cl...  malignant
# ..                                                 ...        ...
# 478  /content/Base de dados de HI Pets/benign/class...     benign
# 68   /content/Base de dados de HI Pets/benign/class...     benign
# 561  /content/Base de dados de HI Pets/benign/class...     benign
# 542  /content/Base de dados de HI Pets/malignant/cl...  malignant
# 183  /content/Base de dados de HI Pets/malignant/cl...  malignant
#
# [473 rows x 2 columns]

# %% [markdown]
# ## Data Augmentation

# %%
width = 224
height = 224
batch_size = 32

gerador_treinamento = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

# %% [markdown]
# ## Teste

# %%
test_gen = ImageDataGenerator(rescale=1/255.0)
test_ds = test_gen.flow_from_dataframe(test_dataset,
                                       x_col='PATH', y_col='LABELS',
                                       target_size=(224,224),
                                       class_mode = 'binary',
                                       color_mode = 'rgb',
                                       batch_size = 32,
                                       shuffle=False)
# Out:
# Found 119 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Funções de métricas

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def evaluate_and_plot(histories, test_ds):
    # Para cada fold
    for fold, history in enumerate(histories, start=1):
        print(f"Fold {fold}:")

        # Prever as classes no conjunto de teste
        test_predictions = history.model.predict(test_ds)

        test_predictions_binary = (test_predictions > 0.5).astype(int)

        y_test = test_ds.labels

        accuracy = accuracy_score(y_test, test_predictions_binary)
        print(f"Accuracy: {accuracy:.2f}")

        class_names = list(test_ds.class_indices.keys())

        report = classification_report(y_test, test_predictions_binary, target_names=class_names)
        print("Classification Report:\n", report)


        confusion = confusion_matrix(y_test, test_predictions_binary)

        plt.figure(figsize=(8, 6))
        sns.heatmap(confusion, annot=True, fmt="d", cmap="Blues", cbar=False)
        plt.xlabel("Predicted Labels")
        plt.ylabel("True Labels")
        plt.title("Confusion Matrix")
        plt.show()

        print("\n")

# %% [markdown]
# Plot da curva ROC

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from scipy import interp

def plot_roc_curves(histories, test_ds):
    fig1 = plt.figure(figsize=[12, 12])
    ax1 = fig1.add_subplot(111, aspect='equal')

    ax1.arrow(0.45, 0.5, -0.25, 0.25, width=0.02, color='green', alpha=0.5)
    ax1.arrow(0.5, 0.45, 0.25, -0.25, width=0.02, color='red', alpha=0.5)

    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for i, history in enumerate(histories):
        test_predictions = history.model.predict(test_ds)

        fpr, tpr, _ = roc_curve(test_ds.labels, test_predictions)
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)
        plt.plot(fpr, tpr, lw=2, alpha=0.3, label='ROC fold %d (AUC = %0.2f)' % (i + 1, roc_auc))

    plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='black')
    mean_tpr = np.mean(tprs, axis=0)
    mean_auc = auc(mean_fpr, mean_tpr)
    plt.plot(mean_fpr, mean_tpr, color='blue',
             label=r'Mean ROC (AUC = %0.2f )' % mean_auc, lw=2, alpha=1)

    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC')
    plt.legend(loc="lower right")
    plt.text(0.32, 0.7, 'More accurate area', fontsize=12)
    plt.text(0.63, 0.4, 'Less accurate area', fontsize=12)
    plt.show()

# %% [markdown]
# ## Sem Pesos BreakHis

# %% [markdown]
# ### Model VGG16

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam

def create_model():
    # Carregar modelo pré-treinado
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Congelar as camadas do modelo pré-treinado
    for layer in base_model.layers:
        layer.trainable = False

    model = Sequential()
    model.add(base_model)
    model.add(BatchNormalization())
    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.4))
    model.add(Dense(256, activation = 'relu'))
    model.add(Dropout(0.4))
    model.add(Dense(1, activation = 'sigmoid'))


    # Compilar o modelo
    model.compile(optimizer=Adam(learning_rate=0.001),
                loss='binary_crossentropy',
                metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])

    return model

# %% [markdown]
# ### Kfold

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import StratifiedKFold

# Defina o número de dobras e épocas
NUM_FOLDS = 10
EPOCHS = 10

# Inicialize a lista para armazenar os históricos
histories_model_imagenet = []

# Inicialize o objeto de validação cruzada estratificada
kfold = StratifiedKFold(n_splits=NUM_FOLDS, shuffle=True, random_state=123)

# Iterar através das dobras
for f, (trn_ind, val_ind) in enumerate(kfold.split(train_dataset['PATH'], train_dataset['LABELS'])):
    print()
    print("#" * 50)
    print("Fold: ", f + 1)
    print("#" * 50)

    training_data = train_dataset.iloc[trn_ind]
    validation_data = train_dataset.iloc[val_ind]

    train_ds = gerador_treinamento.flow_from_dataframe(
        training_data,
        x_col='PATH', y_col='LABELS',
        target_size=(width, height),
        class_mode='binary', color_mode='rgb',
        batch_size=32, shuffle=True
    )
    val_ds = gerador_treinamento.flow_from_dataframe(
        validation_data,
        x_col='PATH', y_col='LABELS',
        target_size=(width, height),
        class_mode='binary', color_mode='rgb',
        batch_size=32, shuffle=False
    )

    model1 = create_model()

    # Criar o callback ModelCheckpoint
    checkpoint = ModelCheckpoint(
        filepath=f'model_wimagenet_checkpoint_fold_{f}.h5',
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )
    callbacks_list = [checkpoint]

    # Treinar o modelo
    history = model1.fit(
        train_ds,
        steps_per_epoch=train_ds.samples // batch_size,
        epochs=EPOCHS,
        callbacks=callbacks_list,
        validation_data=val_ds,
        validation_steps=val_ds.samples // batch_size
    )

    # Armazenar o histórico para cada dobra
    histories_model_imagenet.append(history)

    # Limpar a sessão do TensorFlow
    tf.keras.backend.clear_session()
# Out:
# ##################################################
# Fold:  1
# ##################################################
# Found 425 validated image filenames belonging to 2 classes.
# Found 48 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 1.2920 - accuracy: 0.7481 - precision: 0.8170 - recall: 0.7742 - auc: 0.8107
# Epoch 1: val_accuracy improved from -inf to 0.65625, saving model to model_wimagenet_checkpoint_fold_0.h5
# 13/13 [==============================] - 47s 2s/step - loss: 1.2920 - accuracy: 0.7481 - precision: 0.8170 - recall: 0.7742 - auc: 0.8107 - val_loss: 1.4985 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 1.0000 - val_auc: 0.7338
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 1.1688 - accuracy: 0.7964 - precision: 0.8353 - recall: 0.8421 - auc: 0.8561
# Epoch 2: val_accuracy improved from 0.65625 to 0.68750, saving model to model_wimagenet_checkpoint_fold_0.h5
# 13/13 [==============================] - 28s 2s/step - loss: 1.1688 - accuracy: 0.7964 - precision: 0.8353 - recall: 0.8421 - auc: 0.8561 - val_loss: 1.1982 - val_accuracy: 0.6875 - val_precision: 0.6774 - val_recall: 1.0000 - val_auc: 0.8312
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 0.7387 - accuracy: 0.8753 - precision: 0.8980 - recall: 0.9016 - auc: 0.9222
# Epoch 3: val_accuracy did not improve from 0.68750
# 13/13 [==============================] - 27s 2s/step - loss: 0.7387 - accuracy: 0.8753 - precision: 0.8980 - recall: 0.9016 - auc: 0.9222 - val_loss: 1.2569 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 1.0000 - val_auc: 0.8701
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5771 - accuracy: 0.8957 - precision: 0.9289 - recall: 0.9024 - auc: 0.9469
# Epoch 4: val_accuracy improved from 0.68750 to 0.81250, saving model to model_wimagenet_checkpoint_fold_0.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.5771 - accuracy: 0.8957 - precision: 0.9289 - recall: 0.9024 - auc: 0.9469 - val_loss: 1.0487 - val_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 1.0000 - val_auc: 0.8485
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.6734 - accuracy: 0.8677 - precision: 0.8871 - recall: 0.9016 - auc: 0.9222
# Epoch 5: val_accuracy improved from 0.81250 to 0.87500, saving model to model_wimagenet_checkpoint_fold_0.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.6734 - accuracy: 0.8677 - precision: 0.8871 - recall: 0.9016 - auc: 0.9222 - val_loss: 0.3928 - val_accuracy: 0.8750 - val_precision: 0.9474 - val_recall: 0.8571 - val_auc: 0.9242
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2752 - accuracy: 0.9364 - precision: 0.9545 - recall: 0.9429 - auc: 0.9753
# Epoch 6: val_accuracy did not improve from 0.87500
# 13/13 [==============================] - 26s 2s/step - loss: 0.2752 - accuracy: 0.9364 - precision: 0.9545 - recall: 0.9429 - auc: 0.9753 - val_loss: 0.5324 - val_accuracy: 0.8750 - val_precision: 1.0000 - val_recall: 0.8095 - val_auc: 0.
val_accuracy did not improve from 0.93750
# 13/13 [==============================] - 25s 2s/step - loss: 0.4673 - accuracy: 0.8804 - precision: 0.9057 - recall: 0.9020 - auc: 0.9418 - val_loss: 0.3519 - val_accuracy: 0.9062 - val_precision: 0.9091 - val_recall: 0.9524 - val_auc: 0.9416
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5658 - accuracy: 0.8880 - precision: 0.9036 - recall: 0.9184 - auc: 0.9369
# Epoch 7: val_accuracy did not improve from 0.93750
# 13/13 [==============================] - 26s 2s/step - loss: 0.5658 - accuracy: 0.8880 - precision: 0.9036 - recall: 0.9184 - auc: 0.9369 - val_loss: 0.1438 - val_accuracy: 0.9375 - val_precision: 0.9524 - val_recall: 0.9524 - val_auc: 0.9827
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3472 - accuracy: 0.9211 - precision: 0.9252 - recall: 0.9514 - auc: 0.9547
# Epoch 8: val_accuracy did not improve from 0.93750
# 13/13 [==============================] - 27s 2s/step - loss: 0.3472 - accuracy: 0.9211 - precision: 0.9252 - recall: 0.9514 - auc: 0.9547 - val_loss: 0.0747 - val_accuracy: 0.9375 - val_precision: 0.9524 - val_recall: 0.9524 - val_auc: 0.9957
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9593 - precision: 0.9873 - recall: 0.9474 - auc: 0.9941
# Epoch 9: val_accuracy did not improve from 0.93750
# 13/13 [==============================] - 26s 2s/step - loss: 0.1187 - accuracy: 0.9593 - precision: 0.9873 - recall: 0.9474 - auc: 0.9941 - val_loss: 0.1407 - val_accuracy: 0.9375 - val_precision: 0.9130 - val_recall: 1.0000 - val_auc: 0.9957
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3056 - accuracy: 0.9211 - precision: 0.9189 - recall: 0.9597 - auc: 0.9669
# Epoch 10: val_accuracy improved from 0.93750 to 0.96875, saving model to model_wimagenet_checkpoint_fold_1.h5
# 13/13 [==============================] - 27s 2s/step - loss: 0.3056 - accuracy: 0.9211 - precision: 0.9189 - recall: 0.9597 - auc: 0.9669 - val_loss: 0.0400 - val_accuracy: 0.9688 - val_precision: 1.0000 - val_recall: 0.9524 - val_auc: 1.0000
#
# ##################################################
# Fold:  3
# ##################################################
# Found 425 validated image filenames belonging to 2 classes.
# Found 48 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 1.4722 - accuracy: 0.7277 - precision: 0.7854 - recall: 0.7823 - auc: 0.7597
# Epoch 1: val_accuracy improved from -inf to 0.65625, saving model to model_wimagenet_checkpoint_fold_2.h5
# 13/13 [==============================] - 30s 2s/step - loss: 1.4722 - accuracy: 0.7277 - precision: 0.7854 - recall: 0.7823 - auc: 0.7597 - val_loss: 0.7462 - val_accuracy: 0.6562 - val_precision: 0.6207 - val_recall: 1.0000 - val_auc: 0.9167
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8568 - accuracy: 0.7939 - precision: 0.8313 - recall: 0.8415 - auc: 0.8560
# Epoch 2: val_accuracy did not improve from 0.65625
# 13/13 [==============================] - 29s 2s/step - loss: 0.8568 - accuracy: 0.7939 - precision: 0.8313 - recall: 0.8415 - auc: 0.8560 - val_loss: 1.7054 - val_accuracy: 0.6250 - val_precision: 0.6000 - val_recall: 1.0000 - val_auc: 0.7917
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4671 - accuracy: 0.8753 - precision: 0.8937 - recall: 0.9116 - auc: 0.9330
# Epoch 3: val_accuracy improved from 0.65625 to 0.75000, saving model to model_wimagenet_checkpoint_fold_2.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.4671 - accuracy: 0.8753 - precision: 0.8937 - recall: 0.9116 - auc: 0.9330 - val_loss: 0.3867 - val_accuracy: 0.7500 - val_precision: 0.6923 - val_recall: 1.0000 - val_auc: 0.9841
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.6241 - accuracy: 0.8677 - precision: 0.8947 - recall: 0.8947 - auc: 0.9333
# Epoch 4: val_accuracy improved from 0.75000 to 0.87500, saving model to model_wimagenet_checkpoint_fold_2.h5
# 13/13 [==============================] - 26s 2s/step - loss: 0.6241 - accuracy: 0.8677 - precision: 0.8947 - recall: 0.8947 - auc: 0.9333 - val_loss: 0.2056 - val_accuracy: 0.8750 - val_precision: 0.8500 - val_recall: 0.9444 - val_auc: 0.9821
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5935 - accuracy: 0
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3371 - accuracy: 0.9231 - precision: 0.9423 - recall: 0.9351 - auc: 0.9634
# Epoch 4: val_accuracy improved from 0.87500 to 0.90625, saving model to model_wimagenet_checkpoint_fold_3.h5
# 13/13 [==============================] - 27s 2s/step - loss: 0.3371 - accuracy: 0.9231 - precision: 0.9423 - recall: 0.9351 - auc: 0.9634 - val_loss: 0.1520 - val_accuracy: 0.9062 - val_precision: 0.9130 - val_recall: 0.9545 - val_auc: 0.9773
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4972 - accuracy: 0.8959 - precision: 0.9084 - recall: 0.9268 - auc: 0.9496
# Epoch 5: val_accuracy improved from 0.90625 to 0.96875, saving model to model_wimagenet_checkpoint_fold_3.h5
# 13/13 [==============================] - 30s 2s/step - loss: 0.4972 - accuracy: 0.8959 - precision: 0.9084 - recall: 0.9268 - auc: 0.9496 - val_loss: 0.0698 - val_accuracy: 0.9688 - val_precision: 1.0000 - val_recall: 0.9545 - val_auc: 1.0000
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1971 - accuracy: 0.9340 - precision: 0.9433 - recall: 0.9510 - auc: 0.9793
# Epoch 6: val_accuracy did not improve from 0.96875
# 13/13 [==============================] - 26s 2s/step - loss: 0.1971 - accuracy: 0.9340 - precision: 0.9433 - recall: 0.9510 - auc: 0.9793 - val_loss: 0.1771 - val_accuracy: 0.9375 - val_precision: 1.0000 - val_recall: 0.9091 - val_auc: 0.9864
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.9467 - precision: 0.9749 - recall: 0.9395 - auc: 0.9770
# Epoch 7: val_accuracy did not improve from 0.96875
# 13/13 [==============================] - 25s 2s/step - loss: 0.2316 - accuracy: 0.9467 - precision: 0.9749 - recall: 0.9395 - auc: 0.9770 - val_loss: 0.0699 - val_accuracy: 0.9688 - val_precision: 0.9565 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1614 - accuracy: 0.9492 - precision: 0.9524 - recall: 0.9677 - auc: 0.9816
# Epoch 8: val_accuracy did not improve from 0.96875
# 13/13 [==============================] - 27s 2s/step - loss: 0.1614 - accuracy: 0.9492 - precision: 0.9524 - recall: 0.9677 - auc: 0.9816 - val_loss: 0.1525 - val_accuracy: 0.9375 - val_precision: 0.9545 - val_recall: 0.9545 - val_auc: 0.9909
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.9594 - precision: 0.9595 - recall: 0.9753 - auc: 0.9851
# Epoch 9: val_accuracy did not improve from 0.96875
# 13/13 [==============================] - 26s 2s/step - loss: 0.1592 - accuracy: 0.9594 - precision: 0.9595 - recall: 0.9753 - auc: 0.9851 - val_loss: 0.1707 - val_accuracy: 0.9375 - val_precision: 1.0000 - val_recall: 0.9091 - val_auc: 0.9955
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.9518 - precision: 0.9712 - recall: 0.9516 - auc: 0.9808
# Epoch 10: val_accuracy did not improve from 0.96875
# 13/13 [==============================] - 26s 2s/step - loss: 0.2316 - accuracy: 0.9518 - precision: 0.9712 - recall: 0.9516 - auc: 0.9808 - val_loss: 0.1661 - val_accuracy: 0.9062 - val_precision: 0.8800 - val_recall: 1.0000 - val_auc: 0.9818
#
# ##################################################
# Fold:  5
# ##################################################
# Found 426 validated image filenames belonging to 2 classes.
# Found 47 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 1.2558 - accuracy: 0.7139 - precision: 0.7773 - recall: 0.7625 - auc: 0.7731
# Epoch 1: val_accuracy improved from -inf to 0.68750, saving model to model_wimagenet_checkpoint_fold_4.h5
# 13/13 [==============================] - 31s 2s/step - loss: 1.2558 - accuracy: 0.7139 - precision: 0.7773 - recall: 0.7625 - auc: 0.7731 - val_loss: 0.6661 - val_accuracy: 0.6875 - val_precision: 0.7200 - val_recall: 0.8571 - val_auc: 0.7922
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8505 - accuracy: 0.8223 - precision: 0.8577 - recall: 0.8577 - auc: 0.8962
# Epoch 2: val_accuracy improved from 0.68750 to 0.71875, saving model to model_wimagenet_checkpoint_fold_4.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.8505 - accuracy: 0.8223 - precision: 0.8577 - recall: 0.8577 - auc: 0.8962 - val_loss: 0.6065 - val_accuracy: 0.7188 - val_precision: 0.7308 - val_recall: 0.9048 - val_auc: 0.8312
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8046 - accuracy: 0.8299 - precision: 0.8653 - recall: 0.8618 - auc: 0.8929
# Epoch 3: val_accuracy improved from 0.71875 to 0.75000, saving model to model_wimagenet_checkpoint_fold_4.h5
# 13/13 [==============================] - 27s 2s/step - loss: 0.8046 - accuracy: 0.8299 - precision: 0.8653 - recall: 0.8618 - auc: 0.8929 - val_loss: 0.5168 - val_accuracy: 0.7500 - val_precision: 0.7826 - val_recall: 0.8571 - val_auc: 0.8853
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.6086 - accuracy: 0.8858 - precision: 0.9084 - recall: 0.9120 - auc: 0.9260
# Epoch 4: val_accuracy improved from 0.75000 to 0.87500, saving model to model_wimagenet_checkpoint_fold_4.h5
# 13/13 [==============================] - 29s 2s/step - loss: 0.6086 - accuracy: 0.8858 - precision: 0.9084 - recall: 0.9120 - auc: 0.9260 - val_loss: 0.4261 - val_accuracy: 0.8750 - val_precision: 1.0000 - val_recall: 0.8095 - val_auc: 0.9221
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3079 - accuracy: 0.9264 - precision: 0.9289 - recall: 0.9553 - auc: 0.9668
# Epoch 5: val_accuracy did not improve from 0.87500
# 13/13 [==============================] - 28s 2s/step - loss: 0.3079 - accuracy: 0.9264 - precision: 0.9289 - recall: 0.9553 - auc: 0.9668 - val_loss: 0.4106 - val_accuracy: 0.8125 - val_precision: 1.0000 - val_recall: 0.7143 - val_auc: 0.9610
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.9340 - precision: 0.9375 - recall: 0.9600 - auc: 0.9707
# Epoch 6: val_accuracy did not improve from 0.87500
# 13/13 [==============================] - 28s 2s/step - loss: 0.2819 - accuracy: 0.9340 - precision: 0.9375 - recall: 0.9600 - auc: 0.9707 - val_loss: 0.5735 - val_accuracy: 0.7500 - val_precision: 0.9333 - val_recall: 0.6667 - val_auc: 0.9177
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3954 - accuracy: 0.9086 - precision: 0.9309 - recall: 0.9234 - auc: 0.9523
# Epoch 7: val_accuracy did not improve from 0.87500
# 13/13 [==============================] - 28s 2s/step - loss: 0.3954 - accuracy: 0.9086 - precision: 0.9309 - recall: 0.9234 - auc: 0.9523 - val_loss: 0.4346 - val_accuracy: 0.8750 - val_precision: 0.9048 - val_recall: 0.9048 - val_auc: 0.9307
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1438 - accuracy: 0.9518 - precision: 0.9636 - recall: 0.9597 - auc: 0.9888
# Epoch 8: val_accuracy did not improve from 0.87500
# 13/13 [==============================] - 28s 2s/step - loss: 0.1438 - accuracy: 0.9518 - precision: 0.9636 - recall: 0.9597 - auc: 0.9888 - val_loss: 0.4409 - val_accuracy: 0.8750 - val_precision: 1.0000 - val_recall: 0.8095 - val_auc: 0.9459
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.9543 - precision: 0.9640 - recall: 0.9640 - auc: 0.9741
# Epoch 9: val_accuracy did not improve from 0.87500
# 13/13 [==============================] - 28s 2s/step - loss: 0.2531 - accuracy: 0.9543 - precision: 0.9640 - recall: 0.9640 - auc: 0.9741 - val_loss: 0.4700 - val_accuracy: 0.8750 - val_precision: 0.9474 - val_recall: 0.8571 - val_auc: 0.9156
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3107 - accuracy: 0.9442 - precision: 0.9551 - recall: 0.9551 - auc: 0.9663
# Epoch 10: val_accuracy improved from 0.87500 to 0.90625, saving model to model_wimagenet_checkpoint_fold_4.h5
# 13/13 [==============================] - 27s 2s/step - loss: 0.3107 - accuracy: 0.9442 - precision: 0.9551 - recall: 0.9551 - auc: 0.9663 - val_loss: 0.1896 - val_accuracy: 0.9062 - val_precision: 0.9091 - val_recall: 0.9524 - val_auc: 0.9870
#
# ##################################################
# Fold:  6
# ##################################################
# Found 426 validated image filenames belonging to 2 classes.
# Found 47 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 1.3854 - accuracy: 0.7310 - precision: 0.7918 - recall: 0.7791 - auc: 0.7619
# Epoch 1: val_accuracy improved from -inf to 0.71875, saving model to model_wimagenet_checkpoint_fold_5.h5
# 13/13 [==============================] - 30s 2s/step - loss: 1.3854 - accuracy: 0.7310 - precision: 0.7918 - recall: 0.7791 - auc: 0.7619 - val_loss: 0.7632 - val_accuracy: 0.7188 - val_precision: 0.7000 - val_recall: 1.0000 - val_auc: 0.8983
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 0
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3291 - accuracy: 0.9365 - precision: 0.9484 - recall: 0.9522 - auc: 0.9673
# Epoch 9: val_accuracy did not improve from 0.93750
# 13/13 [==============================] - 27s 2s/step - loss: 0.3291 - accuracy: 0.9365 - precision: 0.9484 - recall: 0.9522 - auc: 0.9673 - val_loss: 0.2357 - val_accuracy: 0.8750 - val_precision: 0.8696 - val_recall: 0.9524 - val_auc: 0.9740
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3170 - accuracy: 0.9518 - precision: 0.9427 - recall: 0.9841 - auc: 0.9740
# Epoch 10: val_accuracy improved from 0.93750 to 0.96875, saving model to model_wimagenet_checkpoint_fold_9.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.3170 - accuracy: 0.9518 - precision: 0.9427 - recall: 0.9841 - auc: 0.9740 - val_loss: 0.0851 - val_accuracy: 0.9688 - val_precision: 0.9545 - val_recall: 1.0000 - val_auc: 0.9957

# %% [markdown]
# ### Métricas de cada FOLD

# %%
evaluate_and_plot(histories_model_imagenet, test_ds)
# Out:
# Fold 1:
# 4/4 [==============================] - 9s 3s/step
# Accuracy: 0.95
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.88      1.00      0.94        44
#    malignant       1.00      0.92      0.96        75
#
#     accuracy                           0.95       119
#    macro avg       0.94      0.96      0.95       119
# weighted avg       0.96      0.95      0.95       119
# Fold 2:
# 4/4 [==============================] - 5s 1s/step
# Accuracy: 0.92
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.83      1.00      0.91        44
#    malignant       1.00      0.88      0.94        75
#
#     accuracy                           0.92       119
#    macro avg       0.92      0.94      0.92       119
# weighted avg       0.94      0.92      0.93       119
# Fold 3:
# 4/4 [==============================] - 6s 2s/step
# Accuracy: 0.97
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.92      1.00      0.96        44
#    malignant       1.00      0.95      0.97        75
#
#     accuracy                           0.97       119
#    macro avg       0.96      0.97      0.96       119
# weighted avg       0.97      0.97      0.97       119
# Fold 4:
# 4/4 [==============================] - 5s 1s/step
# Accuracy: 0.92
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.81      1.00      0.90        44
#    malignant       1.00      0.87      0.93        75
#
#     accuracy                           0.92       119
#    macro avg       0.91      0.93      0.91       119
# weighted avg       0.93      0.92      0.92       119
# Fold 5:
# 4/4 [==============================] - 6s 2s/step
# Accuracy: 0.95
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.88      1.00      0.94        44
#    malignant       1.00      0.92      0.96        75
#
#     accuracy                           0.95       119
#    macro avg       0.94      0.96      0.95       119
# weighted avg       0.96      0.95      0.95       119
# Fold 6:
# 4/4 [==============================] - 5s 1s/step
# Accuracy: 0.96
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.90      1.00      0.95        44
#    malignant       1.00      0.93      0.97        75
#
#     accuracy                           0.96       119
#    macro avg       0.95      0.97      0.96       119
# weighted avg       0.96      0.96      0.96       119
# Fold 7:
# 4/4 [==============================] - 7s 2s/step
# Accuracy: 0.90
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.79      1.00      0.88        44
#    malignant       1.00      0.84      0.91        75
#
#     accuracy                           0.90       119
#    macro avg       0.89      0.92      0.90       119
# weighted avg       0.92      0.90      0.90       119
# Fold 8:
# 4/4 [==============================] - 5s 1s/step
# Accuracy: 0.93
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.85      1.00      0.92        44
#    malignant       1.00      0.89      0.94        75
#
#     accuracy                           0.93       119
#    macro avg       0.92      0.95      0.93       119
# weighted avg       0.94      0.93      0.93       119
# Fold 9:
# 4/4 [==============================] - 6s 2s/step
# Accuracy: 0.96
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.90      1.00      0.95        44
#    malignant       1.00      0.93      0.97        75
#
#     accuracy                           0.96       119
#    macro avg       0.95      0.97      0.96       119
# weighted avg       0.96      0.96      0.96       119
# Fold 10:
# 4/4 [==============================] - 5s 1s/step
# Accuracy: 0.92
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.83      1.00      0.91        44
#    malignant       1.00      0.88      0.94        75
#
#     accuracy                           0.92       119
#    macro avg       0.92      0.94      0.92       119
# weighted avg       0.94      0.92      0.93       119

# %% [markdown]
# ### Plot da curva ROC

# %%
plot_roc_curves(histories_model_imagenet, test_ds)
# Out:
# 4/4 [==============================] - 6s 2s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 6s 2s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 6s 2s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 6s 2s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step

# %% [markdown]
# ## Com Pesos BreaKHis

# %% [markdown]
# ### Model

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam

def create_transfer_mode_weightsBreaKHis(weights_path):
    # Carregar modelo pré-treinado
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Congelar as camadas do modelo pré-treinado
    for layer in base_model.layers:
        layer.trainable = False

    model = Sequential()
    model.add(base_model)
    model.add(BatchNormalization())
    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.4))
    model.add(Dense(256, activation = 'relu'))
    model.add(Dropout(0.4))
    model.add(Dense(1, activation = 'sigmoid'))

    base_model.load_weights(weights_path, by_name=True)

    # Compilar o modelo
    model.compile(optimizer=Adam(learning_rate=0.001),
                loss='binary_crossentropy',
                metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])

    return model

# %% [markdown]
# ### Pesos

# %%
# Caminho para o arquivo .h5 com os pesos pré-treinados
weights_path = '/content/drive/MyDrive/vgg16_BreaKHis_model2.h5'

# %% [markdown]
# ### Kfold

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf

EPOCHS = 10
histories_model_weights_breakhis = []

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=123)

for f, (trn_ind, val_ind) in enumerate(skf.split(train_dataset, train_dataset['LABELS'])):
    print()
    print("#" * 50)
    print("Fold: ", f + 1)
    print("#" * 50)

    training_data = train_dataset.iloc[trn_ind]
    validation_data = train_dataset.iloc[val_ind]

    train_ds2 = gerador_treinamento.flow_from_dataframe(training_data,
                                                        x_col='PATH', y_col='LABELS',
                                                        target_size=(width, height),
                                                        class_mode='binary', color_mode='rgb',
                                                        batch_size=32, shuffle=True)
    print(train_ds2.class_indices)
    val_ds2 = gerador_treinamento.flow_from_dataframe(validation_data,
                                                      x_col='PATH', y_col='LABELS',
                                                      target_size=(width, height),
                                                      class_mode='binary', color_mode='rgb',
                                                      batch_size=32, shuffle=False)

    model = create_transfer_mode_weightsBreaKHis(weights_path)


    # Treinar o modelo
    history2 = model.fit(
        train_ds2,
        steps_per_epoch=train_ds2.samples // batch_size,
        epochs=EPOCHS,
        validation_data=val_ds2,
        validation_steps=val_ds2.samples // batch_size
    )

    # store history pra cada fold
    histories_model_weights_breakhis.append(history2)

    tf.keras.backend.clear_session()
# Out:
# ##################################################
# Fold:  1
# ##################################################
# Found 425 validated image filenames belonging to 2 classes.
# {'benign': 0, 'malignant': 1}
# Found 48 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 13/13 [==============================] - 29s 2s/step - loss: 1.5049 - accuracy: 0.7048 - precision: 0.7745 - recall: 0.7429 - auc: 0.7499 - val_loss: 0.6997 - val_accuracy: 0.6562 - val_precision: 0.6786 - val_recall: 0.9048 - val_auc: 0.8247
# Epoch 2/10
# 13/13 [==============================] - 26s 2s/step - loss: 0.8863 - accuracy: 0.8293 - precision: 0.8550 - recall: 0.8779 - auc: 0.8790 - val_loss: 0.5709 - val_accuracy: 0.7188 - val_precision: 0.7000 - val_recall: 1.0000 - val_auc: 0.8983
# Epoch 3/10
# 13/13 [==============================] - 29s 2s/step - loss: 0.7901 - accuracy: 0.8448 - precision: 0.8807 - recall: 0.8699 - auc: 0.9171 - val_loss: 0.3079 - val_accuracy: 0.8125 - val_precision: 0.8000 - val_recall: 0.9524 - val_auc: 0.9610
# Epoch 4/10
# 13/13 [==============================] - 26s 2s/step - loss: 0.6079 - accuracy: 0.8830 - precision: 0.8876 - recall: 0.9309 - auc: 0.9288 - val_loss: 0.2970 - val_accuracy: 0.8750 - val_precision: 0.8696 - val_recall: 0.9524 - val_auc: 0.9567
# Epoch 5/10
# 13/13 [==============================] - 28s 2s/step - loss: 0.4051 - accuracy: 0.9186 - precision: 0.9461 - recall: 0.9231 - auc: 0.9608 - val_loss: 0.3339 - val_accuracy: 0.8750 - val_precision: 0.8400 - val_recall: 1.0000 - val_auc: 0.9481
# Epoch 6/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.5824 - accuracy: 0.9008 - precision: 0.9150 - recall: 0.9262 - auc: 0.9370 - val_loss: 0.1981 - val_accuracy: 0.8750 - val_precision: 1.0000 - val_recall: 0.8095 - val_auc: 0.9957
# Epoch 7/10
# 13/13 [==============================] - 26s 2s/step - loss: 0.1534 - accuracy: 0.9593 - precision: 0.9675 - recall: 0.9675 - auc: 0.9827 - val_loss: 0.1991 - val_accuracy: 0.9062 - val_precision: 1.0000 - val_recall: 0.
- val_accuracy: 0.8750 - val_precision: 0.8696 - val_recall: 0.9524 - val_auc: 0.9654
# Epoch 3/10
# 13/13 [==============================] - 26s 2s/step - loss: 0.9237 - accuracy: 0.8122 - precision: 0.8531 - recall: 0.8462 - auc: 0.8775 - val_loss: 0.4248 - val_accuracy: 0.8750 - val_precision: 0.8696 - val_recall: 0.9524 - val_auc: 0.9004
# Epoch 4/10
# 13/13 [==============================] - 26s 2s/step - loss: 0.6272 - accuracy: 0.8858 - precision: 0.8941 - recall: 0.9268 - auc: 0.9183 - val_loss: 0.3364 - val_accuracy: 0.9062 - val_precision: 0.9500 - val_recall: 0.9048 - val_auc: 0.9351
# Epoch 5/10
# 13/13 [==============================] - 26s 2s/step - loss: 0.6470 - accuracy: 0.8706 - precision: 0.9024 - recall: 0.8916 - auc: 0.9278 - val_loss: 0.1830 - val_accuracy: 0.9062 - val_precision: 0.9091 - val_recall: 0.9524 - val_auc: 0.9654
# Epoch 6/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.6312 - accuracy: 0.8832 - precision: 0.9051 - recall: 0.9124 - auc: 0.9346 - val_loss: 0.7307 - val_accuracy: 0.8125 - val_precision: 0.7778 - val_recall: 1.0000 - val_auc: 0.8831
# Epoch 7/10
# 13/13 [==============================] - 26s 2s/step - loss: 0.6316 - accuracy: 0.9010 - precision: 0.9274 - recall: 0.9163 - auc: 0.9321 - val_loss: 0.1214 - val_accuracy: 0.9375 - val_precision: 0.9130 - val_recall: 1.0000 - val_auc: 0.9957
# Epoch 8/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.2442 - accuracy: 0.9289 - precision: 0.9363 - recall: 0.9514 - auc: 0.9755 - val_loss: 0.0670 - val_accuracy: 0.9688 - val_precision: 1.0000 - val_recall: 0.9524 - val_auc: 1.0000
# Epoch 9/10
# 13/13 [==============================] - 26s 2s/step - loss: 0.1564 - accuracy: 0.9543 - precision: 0.9679 - recall: 0.9602 - auc: 0.9882 - val_loss: 0.0599 - val_accuracy: 0.9688 - val_precision: 1.0000 - val_recall: 0.9524 - val_auc: 1.0000
# Epoch 10/10
# 13/13 [==============================] - 28s 2s/step - loss: 0.2589 - accuracy: 0.9518 - precision: 0.9631 - recall: 0.9592 - auc: 0.9781 - val_loss: 0.6410 - val_accuracy: 0.8438 - val_precision: 0.8077 - val_recall: 1.0000 - val_auc: 0.9416
#
# ##################################################
# Fold:  7
# ##################################################
# Found 426 validated image filenames belonging to 2 classes.
# {'benign': 0, 'malignant': 1}
# Found 47 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 13/13 [==============================] - 29s 2s/step - loss: 1.4885 - accuracy: 0.7208 - precision: 0.7828 - recall: 0.7702 - auc: 0.7654 - val_loss: 0.4740 - val_accuracy: 0.8438 - val_precision: 0.9091 - val_recall: 0.8696 - val_auc: 0.8696
# Epoch 2/10
# 13/13 [==============================] - 26s 2s/step - loss: 1.2989 - accuracy: 0.7919 - precision: 0.8400 - recall: 0.8333 - auc: 0.8397 - val_loss: 0.9786 - val_accuracy: 0.7500 - val_precision: 0.7419 - val_recall: 1.0000 - val_auc: 0.8841
# Epoch 3/10
# 13/13 [==============================] - 25s 2s/step - loss: 0.9301 - accuracy: 0.8604 - precision: 0.8967 - recall: 0.8785 - auc: 0.8885 - val_loss: 0.2493 - val_accuracy: 0.8750 - val_precision: 0.9130 - val_recall: 0.9130 - val_auc: 0.9469
# Epoch 4/10
# 13/13 [==============================] - 28s 2s/step - loss: 0.5452 - accuracy: 0.8731 - precision: 0.8885 - recall: 0.9167 - auc: 0.9336 - val_loss: 0.0744 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 5/10
# 13/13 [==============================] - 26s 2s/step - loss: 0.3630 - accuracy: 0.9061 - precision: 0.9265 - recall: 0.9228 - auc: 0.9597 - val_loss: 0.1677 - val_accuracy: 0.9375 - val_precision: 0.9565 - val_recall: 0.9565 - val_auc: 0.9710
# Epoch 6/10
# 13/13 [==============================] - 25s 2s/step - loss: 0.3527 - accuracy: 0.9264 - precision: 0.9587 - recall: 0.9243 - auc: 0.9656 - val_loss: 0.1841 - val_accuracy: 0.8750 - val_precision: 0.9130 - val_recall: 0.9130 - val_auc: 0.9710
# Epoch 7/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.2983 - accuracy: 0.9264 - precision: 0.9500 - recall: 0.9306 - auc: 0.9648 - val_loss: 0.2975 - val_accuracy: 0.9062 - val_precision: 1.0000 - val_recall: 0.8696 - val_auc: 0.9565
# Epoch 8/10
# 13/13 [==============================] - 26s 2s/step - loss: 0
10
# 13/13 [==============================] - 26s 2s/step - loss: 0.5426 - accuracy: 0.8756 - precision: 0.9129 - recall: 0.8871 - auc: 0.9285 - val_loss: 0.1703 - val_accuracy: 0.9375 - val_precision: 0.9091 - val_recall: 1.0000 - val_auc: 0.9958
# Epoch 5/10
# 13/13 [==============================] - 24s 2s/step - loss: 0.4954 - accuracy: 0.8985 - precision: 0.9120 - recall: 0.9268 - auc: 0.9380 - val_loss: 0.3315 - val_accuracy: 0.9375 - val_precision: 0.9091 - val_recall: 1.0000 - val_auc: 0.9500
# Epoch 6/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.6003 - accuracy: 0.8680 - precision: 0.8971 - recall: 0.8898 - auc: 0.9333 - val_loss: 0.0672 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 7/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.2490 - accuracy: 0.9391 - precision: 0.9593 - recall: 0.9440 - auc: 0.9732 - val_loss: 0.0659 - val_accuracy: 0.9688 - val_precision: 1.0000 - val_recall: 0.9500 - val_auc: 1.0000
# Epoch 8/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.2166 - accuracy: 0.9391 - precision: 0.9476 - recall: 0.9553 - auc: 0.9759 - val_loss: 0.0609 - val_accuracy: 0.9688 - val_precision: 1.0000 - val_recall: 0.9500 - val_auc: 0.9958
# Epoch 9/10
# 13/13 [==============================] - 26s 2s/step - loss: 0.2622 - accuracy: 0.9315 - precision: 0.9461 - recall: 0.9421 - auc: 0.9741 - val_loss: 0.0420 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 10/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.0763 - accuracy: 0.9695 - precision: 0.9755 - recall: 0.9755 - auc: 0.9960 - val_loss: 0.0242 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
#
# ##################################################
# Fold:  10
# ##################################################
# Found 426 validated image filenames belonging to 2 classes.
# {'benign': 0, 'malignant': 1}
# Found 47 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 13/13 [==============================] - 32s 2s/step - loss: 1.4909 - accuracy: 0.6853 - precision: 0.7490 - recall: 0.7429 - auc: 0.7154 - val_loss: 0.6208 - val_accuracy: 0.6250 - val_precision: 0.6452 - val_recall: 0.9524 - val_auc: 0.8831
# Epoch 2/10
# 13/13 [==============================] - 24s 2s/step - loss: 0.7400 - accuracy: 0.8071 - precision: 0.8392 - recall: 0.8594 - auc: 0.8681 - val_loss: 0.7212 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 1.0000 - val_auc: 0.8766
# Epoch 3/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.5565 - accuracy: 0.8452 - precision: 0.8838 - recall: 0.8659 - auc: 0.9136 - val_loss: 0.3798 - val_accuracy: 0.8750 - val_precision: 0.8400 - val_recall: 1.0000 - val_auc: 0.9437
# Epoch 4/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.4413 - accuracy: 0.8807 - precision: 0.8996 - recall: 0.9106 - auc: 0.9368 - val_loss: 0.4687 - val_accuracy: 0.8750 - val_precision: 0.8696 - val_recall: 0.9524 - val_auc: 0.8810
# Epoch 5/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.3912 - accuracy: 0.8909 - precision: 0.9218 - recall: 0.9032 - auc: 0.9492 - val_loss: 0.2056 - val_accuracy: 0.9375 - val_precision: 0.9130 - val_recall: 1.0000 - val_auc: 0.9740
# Epoch 6/10
# 13/13 [==============================] - 25s 2s/step - loss: 0.3784 - accuracy: 0.8909 - precision: 0.9180 - recall: 0.9069 - auc: 0.9551 - val_loss: 0.2486 - val_accuracy: 0.9062 - val_precision: 0.8750 - val_recall: 1.0000 - val_auc: 0.9913
# Epoch 7/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.2652 - accuracy: 0.9061 - precision: 0.9170 - recall: 0.9355 - auc: 0.9748 - val_loss: 0.1736 - val_accuracy: 0.9062 - val_precision: 0.9091 - val_recall: 0.9524 - val_auc: 0.9827
# Epoch 8/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.1444 - accuracy: 0.9467 - precision: 0.9512 - recall: 0.9630 - auc: 0.9908 - val_loss: 0.3860 - val_accuracy: 0.9062 - val_precision: 0.8750 - val_recall: 1.0000 - val_auc: 0.9351
# Epoch 9/10
# 13/13 [==============================] - 25s 2s/step - loss: 0.3133 - accuracy: 0.9188 - precision: 0.9395 - recall: 0.9320 - auc: 0.9699 - val_loss: 0.1843 - val_accuracy: 0.9688 - val_precision: 0.9545 - val_recall: 1.0000 - val_auc: 0.9870
# Epoch 10/10
# 13/13 [==============================] - 27s 2s/step - loss: 0.1371 - accuracy: 0.9518 - precision: 0.9556 - recall: 0.9673 - auc: 0.9909 - val_loss: 0.1661 - val_accuracy: 0.9375 - val_precision: 0.9130 - val_recall: 1.0000 - val_auc: 0.9870

# %% [markdown]
# ### Métricas de cada FOLD

# %%
evaluate_and_plot(histories_model_weights_breakhis, test_ds)
# Out:
# Fold 1:
# 4/4 [==============================] - 6s 2s/step
# Accuracy: 0.98
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.96      1.00      0.98        44
#    malignant       1.00      0.97      0.99        75
#
#     accuracy                           0.98       119
#    macro avg       0.98      0.99      0.98       119
# weighted avg       0.98      0.98      0.98       119
# Fold 2:
# 4/4 [==============================] - 5s 1s/step
# Accuracy: 0.91
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.80      1.00      0.89        44
#    malignant       1.00      0.85      0.92        75
#
#     accuracy                           0.91       119
#    macro avg       0.90      0.93      0.90       119
# weighted avg       0.93      0.91      0.91       119
# Fold 3:
# 4/4 [==============================] - 6s 2s/step
# Accuracy: 0.91
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.80      1.00      0.89        44
#    malignant       1.00      0.85      0.92        75
#
#     accuracy                           0.91       119
#    macro avg       0.90      0.93      0.90       119
# weighted avg       0.93      0.91      0.91       119
# Fold 4:
# 4/4 [==============================] - 5s 1s/step
# Accuracy: 0.96
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.90      1.00      0.95        44
#    malignant       1.00      0.93      0.97        75
#
#     accuracy                           0.96       119
#    macro avg       0.95      0.97      0.96       119
# weighted avg       0.96      0.96      0.96       119
# Fold 5:
# 4/4 [==============================] - 6s 2s/step
# Accuracy: 0.92
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.83      1.00      0.91        44
#    malignant       1.00      0.88      0.94        75
#
#     accuracy                           0.92       119
#    macro avg       0.92      0.94      0.92       119
# weighted avg       0.94      0.92      0.93       119
# Fold 6:
# 4/4 [==============================] - 5s 1s/step
# Accuracy: 0.92
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.87      0.91      0.89        44
#    malignant       0.95      0.92      0.93        75
#
#     accuracy                           0.92       119
#    macro avg       0.91      0.91      0.91       119
# weighted avg       0.92      0.92      0.92       119
# Fold 7:
# 4/4 [==============================] - 6s 2s/step
# Accuracy: 0.94
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.88      0.98      0.92        44
#    malignant       0.99      0.92      0.95        75
#
#     accuracy                           0.94       119
#    macro avg       0.93      0.95      0.94       119
# weighted avg       0.95      0.94      0.94       119
# Fold 8:
# 4/4 [==============================] - 5s 1s/step
# Accuracy: 0.92
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.83      1.00      0.91        44
#    malignant       1.00      0.88      0.94        75
#
#     accuracy                           0.92       119
#    macro avg       0.92      0.94      0.92       119
# weighted avg       0.94      0.92      0.93       119
# Fold 9:
# 4/4 [==============================] - 6s 1s/step
# Accuracy: 0.92
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.83      1.00      0.91        44
#    malignant       1.00      0.88      0.94        75
#
#     accuracy                           0.92       119
#    macro avg       0.92      0.94      0.92       119
# weighted avg       0.94      0.92      0.93       119
# Fold 10:
# 4/4 [==============================] - 5s 1s/step
# Accuracy: 0.92
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.81      1.00      0.90        44
#    malignant       1.00      0.87      0.93        75
#
#     accuracy                           0.92       119
#    macro avg       0.91      0.93      0.91       119
# weighted avg       0.93      0.92      0.92       119

# %% [markdown]
# ### Plot da curva ROC

# %%
plot_roc_curves(histories_model_weights_breakhis, test_ds)
# Out:
# 4/4 [==============================] - 6s 2s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 6s 2s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 6s 2s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step

# %% [markdown]
# ## Comparação dos dois resultados em Curva ROC

# %%
def plot_mean_roc_media(histories_list, test_ds):
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    for i, histories in enumerate(histories_list):
        mean_fpr = np.linspace(0, 1, 100)
        tpr_sum = np.zeros(100)

        for history in histories:

            test_predictions = history.model.predict(test_ds)

            fpr, tpr, _ = roc_curve(test_ds.labels, test_predictions)
            tpr_sum += np.interp(mean_fpr, fpr, tpr)

        mean_tpr = tpr_sum / len(histories)

        mean_auc = auc(mean_fpr, mean_tpr)

        # Plotar a curva ROC média
        ax = axes[i]
        ax.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f})')
        ax.plot([0, 1], [0, 1], color='gray', linestyle='--')
        ax.set_xlabel('False Positive Rate')
        ax.set_ylabel('True Positive Rate')
        ax.set_title(f'Mean ROC Curve - Set {i+1}')
        ax.legend(loc='lower right')

    plt.tight_layout()
    plt.show()


plot_mean_roc_media([histories_model_imagenet, histories_model_weights_breakhis], test_ds)
# Out:
# 4/4 [==============================] - 6s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 6s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 6s 2s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 6s 2s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 6s 2s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 6s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 6s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 5s 1s/step

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_curve, auc

def plot_mean_roc_media(histories_list, test_ds):
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))

    for i, histories in enumerate(histories_list):
        mean_fpr = np.linspace(0, 1, 100)
        tpr_sum = np.zeros(100)

        for history in histories:
            test_predictions = history.model.predict(test_ds)
            fpr, tpr, _ = roc_curve(test_ds.labels, test_predictions)
            tpr_sum += np.interp(mean_fpr, fpr, tpr)

        mean_tpr = tpr_sum / len(histories)
        mean_auc = auc(mean_fpr, mean_tpr)

        plt.plot(mean_fpr, mean_tpr, label=f'Set {i+1} (AUC = {mean_auc:.2f})')

    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Mean ROC Curve')
    plt.legend()
    plt.show()

# Chama a função para plotar as curvas ROC médias
plot_mean_roc_media([histories_model_imagenet, histories_model_weights_breakhis], test_ds)
# Out:
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 6s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 6s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 6s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 6s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 6s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 6s 2s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 6s 2s/step

# %%
from sklearn.metrics import accuracy_score

def calculate_average_accuracy(histories, test_ds):
    fold_accuracies = []

    for fold, history in enumerate(histories, start=1):
        # Prever as classes no conjunto de teste
        test_predictions = history.model.predict(test_ds)
        test_predictions_binary = (test_predictions > 0.5).astype(int)

        y_test = test_ds.labels

        accuracy = accuracy_score(y_test, test_predictions_binary)

        fold_accuracies.append(accuracy)

    avg_accuracy = np.mean(fold_accuracies)
    return avg_accuracy
accuracy_model1 = calculate_average_accuracy(histories_model_imagenet, test_ds)
accuracy_model2 = calculate_average_accuracy(histories_model_weights_breakhis, test_ds)
print('Sem pesos BreakHis:')
print(f"Accuracy: {accuracy_model1:.2f}")
print('Com pesos BreakHis:')
print(f"Accuracy: {accuracy_model2:.2f}")
# Out:
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 6s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 6s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 6s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 6s 2s/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 5s 1s/step
# 4/4 [==============================] - 6s 1s/step
# Sem pesos BreakHis:
# Accuracy: 0.94
# Com pesos BreakHis:
# Accuracy: 0.93
